# %%
import numpy as np

# %%
np.random.rand(1)
# Out:
# array([0.30989419])

# %%
np.random.randn(10)  #random numbers from normal distribution
# Out:
# array([-0.48457799,  0.25389441, -3.51302298, -2.99258078,  1.22225755,
#        -0.21418388, -0.64211839,  1.22625986,  1.5070965 , -0.52869802])

# %%
np.random.randint(0, 101, 5)
# Out:
# array([23, 91, 25, 59, 48], dtype=int32)

# %%
np.random.seed(42)
np.random.rand(4)
# Out:
# array([0.37454012, 0.95071431, 0.73199394, 0.59865848])

# %%
ranarr = np.random.randint(1, 101, 10)

# %%
ranarr
# Out:
# array([ 83,  87,  75,  75,  88, 100,  24,   3,  22,  53], dtype=int32)

# %%
ranarr.max()
# Out:
# np.int32(100)

# %%
ranarr.argmax()
# Out:
# np.int64(5)

# %%
ranarr.min()
# Out:
# np.int32(3)

# %%
ranarr.argmin()
# Out:
# np.int64(7)
